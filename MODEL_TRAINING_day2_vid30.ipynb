# %%
from datasets import load_dataset

raw_datasets = load_dataset("nyu-mll/glue", "mnli")
raw_datasets
# Out:
# /usr/local/lib/python3.13/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# DatasetDict({
#     train: Dataset({
#         features: ['premise', 'hypothesis', 'label', 'idx'],
#         num_rows: 392702
#     })
#     validation_matched: Dataset({
#         features: ['premise', 'hypothesis', 'label', 'idx'],
#         num_rows: 9815
#     })
#     validation_mismatched: Dataset({
#         features: ['premise', 'hypothesis', 'label', 'idx'],
#         num_rows: 9832
#     })
#     test_matched: Dataset({
# ...

# %%
raw_datasets["train"].unique("label")
# Out:
# [1, 0, 2]

# %%
raw_datasets["train"][6]
# Out:
# {'premise': 'But a few Christian mosaics survive above the apse is the Virgin with the infant Jesus, with the Archangel Gabriel to the right (his companion Michael, to the left, has vanished save for a few feathers from his wings).',
#  'hypothesis': 'Most of the Christian mosaics were destroyed by Muslims.  ',
#  'label': 1,
#  'idx': 6}

# %%
raw_datasets["train"][:10]
# Out:
# {'premise': ['Conceptually cream skimming has two basic dimensions - product and geography.',
#   'you know during the season and i guess at at your level uh you lose them to the next level if if they decide to recall the the parent team the Braves decide to call to recall a guy from triple A then a double A guy goes up to replace him and a single A guy goes up to replace him',
#   'One of our number will carry out your instructions minutely.',
#   'How do you know? All this is their information again.',
#   "yeah i tell you what though if you go price some of those tennis shoes i can see why now you know they're getting up in the hundred dollar range",
#   "my walkman broke so i'm upset now i just have to turn the stereo up real loud",
#   'But a few Christian mosaics survive above the apse is the Virgin with the infant Jesus, with the Archangel Gabriel to the right (his companion Michael, to the left, has vanished save for a few feathers from his wings).',
# ...

# %%
raw_datasets["train"].features
# Out:
# {'premise': Value('string'),
#  'hypothesis': Value('string'),
#  'label': ClassLabel(names=['entailment', 'neutral', 'contradiction']),
#  'idx': Value('int32')}

# %%
from transformers import AutoTokenizer
checkpoint="bert-base-cased"
tokenizer= AutoTokenizer.from_pretrained(checkpoint)
def tokenize_function(example):
  return tokenizer(example["premise"], example["hypothesis"], truncation=True)
tokenized_datasets= raw_datasets.map(tokenize_function,batched=True)
print(tokenized_datasets.column_names)
# Out:
# Map:   0%|          | 0/9815 [00:00<?, ? examples/s]
# {'train': ['premise', 'hypothesis', 'label', 'idx', 'input_ids', 'token_type_ids', 'attention_mask'], 'validation_matched': ['premise', 'hypothesis', 'label', 'idx', 'input_ids', 'token_type_ids', 'attention_mask'], 'validation_mismatched': ['premise', 'hypothesis', 'label', 'idx', 'input_ids', 'token_type_ids', 'attention_mask'], 'test_matched': ['premise', 'hypothesis', 'label', 'idx', 'input_ids', 'token_type_ids', 'attention_mask'], 'test_mismatched': ['premise', 'hypothesis', 'label', 'idx', 'input_ids', 'token_type_ids', 'attention_mask']}

# %%
print(tokenized_datasets["train"][:10])
# Out:
# {'premise': ['Conceptually cream skimming has two basic dimensions - product and geography.', 'you know during the season and i guess at at your level uh you lose them to the next level if if they decide to recall the the parent team the Braves decide to call to recall a guy from triple A then a double A guy goes up to replace him and a single A guy goes up to replace him', 'One of our number will carry out your instructions minutely.', 'How do you know? All this is their information again.', "yeah i tell you what though if you go price some of those tennis shoes i can see why now you know they're getting up in the hundred dollar range", "my walkman broke so i'm upset now i just have to turn the stereo up real loud", 'But a few Christian mosaics survive above the apse is the Virgin with the infant Jesus, with the Archangel Gabriel to the right (his companion Michael, to the left, has vanished save for a few feathers from his wings).', "(Read  for Slate 's take on Jackson's findings.)
# ...

# %%
tokenized_datasets["train"]["input_ids"]
# Out:
# Column([[101, 28103, 14795, 7081, 10458, 25004, 1144, 1160, 3501, 10082, 118, 3317, 1105, 14534, 119, 102, 22249, 1105, 14534, 1132, 1184, 1294, 7081, 10458, 25004, 1250, 119, 102], [101, 1128, 1221, 1219, 1103, 1265, 1105, 178, 3319, 1120, 1120, 1240, 1634, 14863, 1128, 3857, 1172, 1106, 1103, 1397, 1634, 1191, 1191, 1152, 4958, 1106, 9148, 1103, 1103, 6486, 1264, 1103, 14864, 4958, 1106, 1840, 1106, 9148, 170, 2564, 1121, 9225, 138, 1173, 170, 2702, 138, 2564, 2947, 1146, 1106, 4971, 1140, 1105, 170, 1423, 138, 2564, 2947, 1146, 1106, 4971, 1140, 102, 1192, 3857, 1103, 1614, 1106, 1103, 1378, 1634, 1191, 1103, 1234, 9148, 119, 102], [101, 1448, 1104, 1412, 1295, 1209, 3564, 1149, 1240, 7953, 2517, 1193, 119, 102, 138, 1420, 1104, 1139, 1264, 1209, 16621, 1240, 3791, 1114, 14934, 13218, 119, 102], [101, 1731, 1202, 1128, 1221, 136, 1398, 1142, 1110, 1147, 1869, 1254, 119, 102, 1188, 1869, 7017, 1106, 1172, 119, 102], [101, 8147, 178, 1587, 1128, 1184, 1463, 1191, 1128, 1301, 3945, 1
# ...

# %%
[len(x) for x in tokenized_datasets["train"]["input_ids"][:10]]
# Out:
# [28, 78, 28, 21, 44, 44, 63, 29, 14, 59]

# %%
tokenized_datasets= tokenized_datasets.remove_columns(["idx","premise","hypothesis"])
tokenized_datasets= tokenized_datasets.rename_columns({"label":"labels"})
tokenized_datasets.set_format("torch")
tokenized_datasets["train"]
# Out:
# Dataset({
#     features: ['labels', 'input_ids', 'token_type_ids', 'attention_mask'],
#     num_rows: 392702
# })

# %%
small_train_dataset= tokenized_datasets["train"].select(range(10))
print(small_train_dataset)
# Out:
# Dataset({
#     features: ['labels', 'input_ids', 'token_type_ids', 'attention_mask'],
#     num_rows: 10
# })

# %%
import sys
print("torchvision" in sys.modules)
# Out:
# False

# %%
from torch.utils.data import DataLoader

# %%
from transformers import DataCollatorWithPadding

data_collator= DataCollatorWithPadding(tokenizer=tokenizer)
train_dataloader=DataLoader(tokenized_datasets["train"],shuffle=True,batch_size=16,collate_fn=data_collator)
for step,batch in enumerate(train_dataloader):
  print(batch["input_ids"].shape)
  if step>5:
    break
# Out:
# torch.Size([16, 91])
# torch.Size([16, 73])
# torch.Size([16, 93])
# torch.Size([16, 91])
# torch.Size([16, 94])
# torch.Size([16, 85])
# torch.Size([16, 79])

# %%
from transformers import AutoModelForSequenceClassification
from transformers import TrainingArguments

checkpoint="bert-base-cased"
model= AutoModelForSequenceClassification.from_pretrained(checkpoint,num_labels=3)
training_args= TrainingArguments(
    "test-trainer", per_device_train_batch_size=16, per_device_eval_batch_size=16, num_train_epochs=5,
    learning_rate=2e-5
)
# Out:
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
print(model.config.num_labels)
# Out:
# 3

# %%
model.config.problem_type = "single_label_classification"

# %%
import torch
from transformers import Trainer, DataCollatorWithPadding

# %%
# !pip uninstall -y torchvision
# Out:
# WARNING: Skipping torchvision as it is not installed.

# %%
import torch

print(torch.__version__)
# Out:
# 2.11.0+cpu

# %%
# !pip uninstall -y torchvision
# Out:
# WARNING: Skipping torchvision as it is not installed.

# %%
import datasets

datasets.config.TORCHVISION_AVAILABLE = False

# %%
from transformers import Trainer

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=small_train_dataset,
    eval_dataset=tokenized_datasets["validation_matched"],
    data_collator=data_collator,

)

trainer.train()
# Out:
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: 3
# wandb: You chose "Don't visualize my results"
# wandb: Using W&B in offline mode.
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.28.1
# W&B syncing is set to <code>`offline`<code> in this directory. Run <code>`wandb online`<code> or set <code>WANDB_MODE=online<code> to enable cloud syncing.<br>Run data is saved locally in <code>/content/wandb/offline-run-20260902_103313-jboa66wk</code><br>View this run in the terminal with <code>`wandb leet`<code>
# /usr/local/lib/python3.13/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
#     <div>
#
# ...

# %%
small_validation = tokenized_datasets["validation_matched"].select(range(100))

predictions = trainer.predict(small_validation)

print(predictions.predictions.shape)
print(predictions.label_ids.shape)
# Out:
# /usr/local/lib/python3.13/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# (100, 3)
# (100,)

# %%
# !pip install evaluate
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 1.4 MB/s eta 0:00:00
# ...

# %%
import numpy as np
import evaluate

metric = evaluate.load("glue", "mnli")

preds = np.argmax(predictions.predictions, axis=-1)

result = metric.compute(
    predictions=preds,
    references=predictions.label_ids
)

print(result)
# Out:
# ...
# {'accuracy': 0.35}

# %% [markdown]
# **Fine Tuning with tf**

# %%
import transformers

print(transformers.__version__)
# Out:
# 4.57.1

# %%
# !pip install transformers==4.57.1

# %%
TFAutoModelForSequenceClassification
# Out:
# transformers.models.auto.modeling_tf_auto.TFAutoModelForSequenceClassification

# %%
import tensorflow as tf
from transformers import TFAutoModelForSequenceClassification # Changed to TFAutoModelForSequenceClassification

checkpoint = "bert-base-cased"

model = TFAutoModelForSequenceClassification.from_pretrained(
    checkpoint,
    num_labels=3,
    use_safetensors=False # Added to bypass safetensors loading issue
)
loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
model.compile(optimizer='adam',loss=loss)
# Out:
# All model checkpoint layers were used when initializing TFBertForSequenceClassification.
#
# Some layers of TFBertForSequenceClassification were not initialized from the model checkpoint at bert-base-cased and are newly initialized: ['classifier']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
small_validation_dataset = tokenized_datasets["validation_matched"].select(range(100))

# %%
tf_train_dataset = model.prepare_tf_dataset(
    small_validation_dataset,
    shuffle=True,
    batch_size=2,
    collate_fn=data_collator
)

tf_validation_dataset = model.prepare_tf_dataset(
    tokenized_datasets["validation_matched"],
    shuffle=False,
    batch_size=16,
    collate_fn=data_collator
)

# %%
print("Train batches:", tf_train_dataset.cardinality().numpy())
print("Validation batches:", tf_validation_dataset.cardinality().numpy())
# Out:
# Train batches: 50
# Validation batches: 614

# %%
model.fit(tf_train_dataset,validation_data=tf_validation_dataset,epochs=1)
# Out:
# 50/50 [==============================] - ETA: 0s - loss: 1.4625
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_9571/697651797.py in <cell line: 0>()
# ----> 1 model.fit(tf_train_dataset,validation_data=tf_validation_dataset,epochs=1)
#
# /usr/local/lib/python3.13/dist-packages/transformers/modeling_tf_utils.py in fit(self, *args, **kwargs)
#    1211     def fit(self, *args, **kwargs):
#    1212         args, kwargs = convert_batch_encoding(*args, **kwargs)
# -> 1213         return super().fit(*args, **kwargs)
#    1214
#    1215     @functools.wraps(keras.Model.train_on_batch)
#
# /usr/local/lib/python3.13/dist-packages/tf_keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
# ...

# %% [markdown]
# **Learning rate with tf**

# %%
from tensorflow.keras.optimizers.schedules import PolynomialDecay
num_epochs=1
num_train_steps=len(tf_train_dataset) * num_epochs
lr_scheduler = tf_keras.optimizers.schedules.PolynomialDecay(
    initial_learning_rate=2e-5,
    decay_steps=1000,
    end_learning_rate=0.0,
    power=1.0
)

# %%
# !pip install tf-keras

# %%
import tensorflow as tf

import tf_keras

opt = tf_keras.optimizers.Adam(
    learning_rate=lr_scheduler
)

model.compile(
    optimizer=opt,
    loss=loss,
    metrics=["accuracy"]
)

# %%
model.fit(tf_train_dataset,epochs=1)
# Out:
#  4/50 [=>............................] - ETA: 5:08 - loss: 1.1607 - accuracy: 0.3750
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_9571/973844009.py in <cell line: 0>()
# ----> 1 model.fit(tf_train_dataset,epochs=1)
#
# /usr/local/lib/python3.13/dist-packages/transformers/modeling_tf_utils.py in fit(self, *args, **kwargs)
#    1211     def fit(self, *args, **kwargs):
#    1212         args, kwargs = convert_batch_encoding(*args, **kwargs)
# -> 1213         return super().fit(*args, **kwargs)
#    1214
#    1215     @functools.wraps(keras.Model.train_on_batch)
#
# /usr/local/lib/python3.13/dist-packages/tf_keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
# ...

# %%
preds = model.predict(tf_validation_dataset).logits

probabilities = tf.nn.softmax(preds)

class_preds = tf.argmax(probabilities, axis=-1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_9571/1528463452.py in <cell line: 0>()
# ----> 1 preds = model.predict(tf_validation_dataset).logits
#       2
#       3 probabilities = tf.nn.softmax(preds)
#       4
#       5 class_preds = tf.argmax(probabilities, axis=-1)
#
# /usr/local/lib/python3.13/dist-packages/transformers/modeling_tf_utils.py in predict(self, *args, **kwargs)
#    1231     def predict(self, *args, **kwargs):
#    1232         args, kwargs = convert_batch_encoding(*args, **kwargs)
# -> 1233         return super().predict(*args, **kwargs)
#    1234
#    1235     @functools.wraps(keras.Model.evaluate)
#
# /usr/local/lib/python3.13/dist-packages/tf_keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
# ...

# %%
import evaluate

metric = evaluate.load("glue", "mnli")

result = metric.compute(
    predictions=class_preds.numpy(),
    references=small_validation_dataset["label"]
)

print(result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_9571/533849045.py in <cell line: 0>()
#       4
#       5 result = metric.compute(
# ----> 6     predictions=class_preds.numpy(),
#       7     references=small_validation_dataset["label"]
#       8 )
#
# NameError: name 'class_preds' is not defined

# %%
model.compile(loss=loss,optimizer=opt,metrics=['accuracy'])
model.fit(tf_train_dataset,validation_data=tf_validation_dataset,epochs=1)
